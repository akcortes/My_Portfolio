# %%
! pip install wbgapi
# Out:
# Requirement already satisfied: wbgapi in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (1.0.7)
# Requirement already satisfied: PyYAML in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from wbgapi) (5.4.1)
# Requirement already satisfied: tabulate in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from wbgapi) (0.8.9)
# Requirement already satisfied: requests in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from wbgapi) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from requests->wbgapi) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from requests->wbgapi) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from requests->wbgapi) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from requests->wbgapi) (2020.12.5)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/anak/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb
import numpy as np
import json
import requests
from bs4 import BeautifulSoup

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2021-11-23
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2021-10-10
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# 13    Enterprise Surveys                                                    ESY              3  2021-04-02
# 14    Gender Statistics                                                     GDS              3  2021-09-27
# 15    Global Economic Monitor                                               GEM              3  2020-07-27
# 16    Health Nutrition and Population Statistics                            HNP              3  2021-09-15
# 18    IDA Results Measurement System                                        IDA              3  2021-07-23
# 19    Millennium Development Goals                                          MDG              3  2018-09-19
# 20    Quarterly Public Sector Debt                                          PSD              3  2021-11-01
# 22    Quarterly External Debt Statistics SDDS                               QDS              3  2021-10-29
# 23    Quarterly External Debt Statistics GDDS                               QDG              3  2021-10-29
# 24    Poverty and Equity                                                    POV              3  2021-10-05
# 25    Jobs                                                                  JOB              3  2021-02-17
# 27    Global Economic Prospects                                             GEP              3  2021-06-08
# 28    Global Financial Inclusion                                            FDX              3  2018-10-15
# 29    The Atlas of Social Protection: Indicators of Resilience and Equity   GSP              3  2021-11-04
# 30    Exporter Dynamics Database – Indicators at Country-Year Level         ED1              3  2016-03-31
# 31    Country Policy and Institutional Assessment                           CPI              3  2021-09-16
# 32    Global Financial Development                                          GFD              3  2021-12-03
# 33    G20 Financial Inclusion Indicators                                    G2F              3  2019-02-27
# 34    Global Partnership for Education                                      GPE              3  2013-04-12
# 35    Sustainable Energy for All                                            SE4              3  2018-06-30
# 36    Statistical Capacity Indicators                                       BBS              3  2021-02-03
# 37    LAC Equity Lab                                                        LEL              3  2016-04-06
# 38    Subnational Poverty                                                   SNP              3  2015-04-27
# 39    Health Nutrition and Population Statistics by Wealth Quintile         HNQ              3  2021-06-08
# 40    Population estimates and projections                                  HPP              3  2021-09-15
# 41    Country Partnership Strategy for India (FY2013 - 17)                  CPS              3  2015-05-22
# 43    Adjusted Net Savings                                                  WAT              3  2021-04-27
# 45    Indonesia Database for Policy and Economic Research                   IDD              3  2019-05-07
# 46    Sustainable Development Goals                                         SDG              3  2021-07-02
# 50    Subnational Population                                                SNT              3  2017-09-21
# 54    Joint External Debt Hub                                               JED              3  2021-11-29
# 57    WDI Database Archives                                                 WDA              4  2021-11-05
# 58    Universal Health Coverage                                             UHC              3  2019-04-25
# 59    Wealth Accounts                                                       WAC              3  2021-10-27
# 60    Economic Fitness                                                      EFT              3  2018-04-19
# 61    PPPs Regulatory Quality                                               PRQ              3  2019-04-25
# 62    International Comparison Program (ICP) 2011                           ICP              4  2020-08-24
# 63    Human Capital Index                                                   HCI              3  2020-09-21
# 64    Worldwide Bureaucracy Indicators                                      WBI              3  2021-05-26
# 65    Health Equity and Financial Protection Indicators                     HPI              3  2019-11-06
# 66    Logistics Performance Index                                           LPI              3  2019-10-29
# 67    PEFA 2011                                                             PF1              4  2021-10-25
# 68    PEFA 2016                                                             PF6              4  2021-12-06
# 69    Global Financial Inclusion and Consumer Protection Survey             RFA              3  2019-06-27
# 70    Economic Fitness 2                                                    EF2              3  2019-04-26
# 71    International Comparison Program (ICP) 2005                           IC5              4  2021-09-10
# 73    Global Financial Inclusion and Consumer Protection Survey (Internal)  RFI              3  2019-06-27
# 75    Environment, Social and Governance (ESG) Data                         ESG              3  2021-10-28
# 76    Remittance Prices Worldwide (Sending Countries)                       RWS              3  2020-12-07
# 77    Remittance Prices Worldwide (Receiving Countries)                     RWR              3  2020-12-07
# 78    ICP 2017                                                              IC7              4  2020-10-21
# 79    PEFA_GRPFM                                                            GRP              4  2021-10-27
# 80    Gender Disaggregated Labor Database (GDLD)                            GDL              4  2020-07-25
# 81    International Debt Statistics: DSSI                                   DSI              4  2021-10-10
# 82    Global Public Procurement                                             GPP              3  2021-03-24
# 83    Statistical Performance Indicators (SPI)                              SPI              3  2021-04-01
# 84    Education Policy                                                      EDP              3  2021-05-11
# 85    PEFA_2021_SNG                                                         SNG              4  2021-10-06
# 86    Global Jobs Indicators Database (JOIN)                                JON              3  2021-09-24
# 87    Country Climate and Development Report (CCDR)                         CCD              3  2021-10-08
#       67 elements

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ATG   Antigua and Barbuda                                   LCN       HIC
# AUS   Australia                                             EAS       HIC
# AUT   Austria                                               ECS       HIC
# AZE   Azerbaijan                                            ECS       UMC
# BDI   Burundi                                               SSF       LIC
# BEL   Belgium                                               ECS       HIC
# BEN   Benin                                                 SSF       LMC
# BFA   Burkina Faso                                          SSF       LIC
# BGD   Bangladesh                                            SAS       LMC
# BGR   Bulgaria                                              ECS       UMC
# BHR   Bahrain                                               MEA       HIC
# BHS   Bahamas, The                                          LCN       HIC
# BIH   Bosnia and Herzegovina                                ECS       UMC
# BLR   Belarus                                               ECS       UMC
# BLZ   Belize                                                LCN       LMC
# BMU   Bermuda                                               NAC       HIC
# BOL   Bolivia                                               LCN       LMC
# BRA   Brazil                                                LCN       UMC
# BRB   Barbados                                              LCN       HIC
# BRN   Brunei Darussalam                                     EAS       HIC
# BTN   Bhutan                                                SAS       LMC
# BWA   Botswana                                              SSF       UMC
# CAF   Central African Republic                              SSF       LIC
# CAN   Canada                                                NAC       HIC
# CEB   Central Europe and the Baltics
# CHE   Switzerland                                           ECS       HIC
# CHI   Channel Islands                                       ECS       HIC
# CHL   Chile                                                 LCN       HIC
# CHN   China                                                 EAS       UMC
# CIV   Cote d'Ivoire                                         SSF       LMC
# CMR   Cameroon                                              SSF       LMC
# COD   Congo, Dem. Rep.                                      SSF       LIC
# COG   Congo, Rep.                                           SSF       LMC
# COL   Colombia                                              LCN       UMC
# COM   Comoros                                               SSF       LMC
# CPV   Cabo Verde                                            SSF       LMC
# CRI   Costa Rica                                            LCN       UMC
# CSS   Caribbean small states
# CUB   Cuba                                                  LCN       UMC
# CUW   Curacao                                               LCN       HIC
# CYM   Cayman Islands                                        LCN       HIC
# CYP   Cyprus                                                ECS       HIC
# CZE   Czech Republic                                        ECS       HIC
# DEU   Germany                                               ECS       HIC
# DJI   Djibouti                                              MEA       LMC
# DMA   Dominica                                              LCN       UMC
# DNK   Denmark                                               ECS       HIC
# DOM   Dominican Republic                                    LCN       UMC
# DZA   Algeria                                               MEA       LMC
# EAP   East Asia & Pacific (excluding high income)
# EAR   Early-demographic dividend
# EAS   East Asia & Pacific
# ECA   Europe & Central Asia (excluding high income)
# ECS   Europe & Central Asia
# ECU   Ecuador                                               LCN       UMC
# EGY   Egypt, Arab Rep.                                      MEA       LMC
# EMU   Euro area
# ERI   Eritrea                                               SSF       LIC
# ESP   Spain                                                 ECS       HIC
# EST   Estonia                                               ECS       HIC
# ETH   Ethiopia                                              SSF       LIC
# EUU   European Union
# FCS   Fragile and conflict affected situations
# FIN   Finland                                               ECS       HIC
# FJI   Fiji                                                  EAS       UMC
# FRA   France                                                ECS       HIC
# FRO   Faroe Islands                                         ECS       HIC
# FSM   Micronesia, Fed. Sts.                                 EAS       LMC
# GAB   Gabon                                                 SSF       UMC
# GBR   United Kingdom                                        ECS       HIC
# GEO   Georgia                                               ECS       UMC
# GHA   Ghana                                                 SSF       LMC
# GIB   Gibraltar                                             ECS       HIC
# GIN   Guinea                                                SSF       LIC
# GMB   Gambia, The                                           SSF       LIC
# GNB   Guinea-Bissau                                         SSF       LIC
# GNQ   Equatorial Guinea                                     SSF       UMC
# GRC   Greece                                                ECS       HIC
# GRD   Grenada                                               LCN       UMC
# GRL   Greenland                                             ECS       HIC
# GTM   Guatemala                                             LCN       UMC
# GUM   Guam                                                  EAS       HIC
# GUY   Guyana                                                LCN       UMC
# HIC   High income
# HKG   Hong Kong SAR, China                                  EAS       HIC
# HND   Honduras                                              LCN       LMC
# HPC   Heavily indebted poor countries (HIPC)
# HRV   Croatia                                               ECS       HIC
# HTI   Haiti                                                 LCN       LMC
# HUN   Hungary                                               ECS       HIC
# IBD   IBRD only
# IBT   IDA & IBRD total
# IDA   IDA total
# IDB   IDA blend
# IDN   Indonesia                                             EAS       LMC
# IDX   IDA only
# IMN   Isle of Man                                           ECS       HIC
# IND   India                                                 SAS       LMC
# INX   Not classified
# IRL   Ireland                                               ECS       HIC
# IRN   Iran, Islamic Rep.                                    MEA       LMC
# IRQ   Iraq                                                  MEA       UMC
# ISL   Iceland                                               ECS       HIC
# ISR   Israel                                                MEA       HIC
# ITA   Italy                                                 ECS       HIC
# JAM   Jamaica                                               LCN       UMC
# JOR   Jordan                                                MEA       UMC
# JPN   Japan                                                 EAS       HIC
# KAZ   Kazakhstan                                            ECS       UMC
# KEN   Kenya                                                 SSF       LMC
# KGZ   Kyrgyz Republic                                       ECS       LMC
# KHM   Cambodia                                              EAS       LMC
# KIR   Kiribati                                              EAS       LMC
# KNA   St. Kitts and Nevis                                   LCN       HIC
# KOR   Korea, Rep.                                           EAS       HIC
# KWT   Kuwait                                                MEA       HIC
# LAC   Latin America & Caribbean (excluding high income)
# LAO   Lao PDR                                               EAS       LMC
# LBN   Lebanon                                               MEA       UMC
# LBR   Liberia                                               SSF       LIC
# LBY   Libya                                                 MEA       UMC
# LCA   St. Lucia                                             LCN       UMC
# LCN   Latin America & Caribbean
# LDC   Least developed countries: UN classification
# LIC   Low income
# LIE   Liechtenstein                                         ECS       HIC
# LKA   Sri Lanka                                             SAS       LMC
# LMC   Lower middle income
# LMY   Low & middle income
# LSO   Lesotho                                               SSF       LMC
# LTE   Late-demographic dividend
# LTU   Lithuania                                             ECS       HIC
# LUX   Luxembourg                                            ECS       HIC
# LVA   Latvia                                                ECS       HIC
# MAC   Macao SAR, China                                      EAS       HIC
# MAF   St. Martin (French part)                              LCN       HIC
# MAR   Morocco                                               MEA       LMC
# MCO   Monaco                                                ECS       HIC
# MDA   Moldova                                               ECS       UMC
# MDG   Madagascar                                            SSF       LIC
# MDV   Maldives                                              SAS       UMC
# MEA   Middle East & North Africa
# MEX   Mexico                                                LCN       UMC
# MHL   Marshall Islands                                      EAS       UMC
# MIC   Middle income
# MKD   North Macedonia                                       ECS       UMC
# MLI   Mali                                                  SSF       LIC
# MLT   Malta                                                 MEA       HIC
# MMR   Myanmar                                               EAS       LMC
# MNA   Middle East & North Africa (excluding high income)
# MNE   Montenegro                                            ECS       UMC
# MNG   Mongolia                                              EAS       LMC
# MNP   Northern Mariana Islands                              EAS       HIC
# MOZ   Mozambique                                            SSF       LIC
# MRT   Mauritania                                            SSF       LMC
# MUS   Mauritius                                             SSF       UMC
# MWI   Malawi                                                SSF       LIC
# MYS   Malaysia                                              EAS       UMC
# NAC   North America
# NAM   Namibia                                               SSF       UMC
# NCL   New Caledonia                                         EAS       HIC
# NER   Niger                                                 SSF       LIC
# NGA   Nigeria                                               SSF       LMC
# NIC   Nicaragua                                             LCN       LMC
# NLD   Netherlands                                           ECS       HIC
# NOR   Norway                                                ECS       HIC
# NPL   Nepal                                                 SAS       LMC
# NRU   Nauru                                                 EAS       HIC
# NZL   New Zealand                                           EAS       HIC
# OED   OECD members
# OMN   Oman                                                  MEA       HIC
# OSS   Other small states
# PAK   Pakistan                                              SAS       LMC
# PAN   Panama                                                LCN       UMC
# PER   Peru                                                  LCN       UMC
# PHL   Philippines                                           EAS       LMC
# PLW   Palau                                                 EAS       HIC
# PNG   Papua New Guinea                                      EAS       LMC
# POL   Poland                                                ECS       HIC
# PRE   Pre-demographic dividend
# PRI   Puerto Rico                                           LCN       HIC
# PRK   Korea, Dem. People's Rep.                             EAS       LIC
# PRT   Portugal                                              ECS       HIC
# PRY   Paraguay                                              LCN       UMC
# PSE   West Bank and Gaza                                    MEA       LMC
# PSS   Pacific island small states
# PST   Post-demographic dividend
# PYF   French Polynesia                                      EAS       HIC
# QAT   Qatar                                                 MEA       HIC
# ROU   Romania                                               ECS       UMC
# RUS   Russian Federation                                    ECS       UMC
# RWA   Rwanda                                                SSF       LIC
# SAS   South Asia
# SAU   Saudi Arabia                                          MEA       HIC
# SDN   Sudan                                                 SSF       LIC
# SEN   Senegal                                               SSF       LMC
# SGP   Singapore                                             EAS       HIC
# SLB   Solomon Islands                                       EAS       LMC
# SLE   Sierra Leone                                          SSF       LIC
# SLV   El Salvador                                           LCN       LMC
# SMR   San Marino                                            ECS       HIC
# SOM   Somalia                                               SSF       LIC
# SRB   Serbia                                                ECS       UMC
# SSA   Sub-Saharan Africa (excluding high income)
# SSD   South Sudan                                           SSF       LIC
# SSF   Sub-Saharan Africa
# SST   Small states
# STP   Sao Tome and Principe                                 SSF       LMC
# SUR   Suriname                                              LCN       UMC
# SVK   Slovak Republic                                       ECS       HIC
# SVN   Slovenia                                              ECS       HIC
# SWE   Sweden                                                ECS       HIC
# SWZ   Eswatini                                              SSF       LMC
# SXM   Sint Maarten (Dutch part)                             LCN       HIC
# SYC   Seychelles                                            SSF       HIC
# SYR   Syrian Arab Republic                                  MEA       LIC
# TCA   Turks and Caicos Islands                              LCN       HIC
# TCD   Chad                                                  SSF       LIC
# TEA   East Asia & Pacific (IDA & IBRD countries)
# TEC   Europe & Central Asia (IDA & IBRD countries)
# TGO   Togo                                                  SSF       LIC
# THA   Thailand                                              EAS       UMC
# TJK   Tajikistan                                            ECS       LMC
# TKM   Turkmenistan                                          ECS       UMC
# TLA   Latin America & the Caribbean (IDA & IBRD countries)
# TLS   Timor-Leste                                           EAS       LMC
# TMN   Middle East & North Africa (IDA & IBRD countries)
# TON   Tonga                                                 EAS       UMC
# TSA   South Asia (IDA & IBRD)
# TSS   Sub-Saharan Africa (IDA & IBRD countries)
# TTO   Trinidad and Tobago                                   LCN       HIC
# TUN   Tunisia                                               MEA       LMC
# TUR   Turkey                                                ECS       UMC
# TUV   Tuvalu                                                EAS       UMC
# TZA   Tanzania                                              SSF       LMC
# UGA   Uganda                                                SSF       LIC
# UKR   Ukraine                                               ECS       LMC
# UMC   Upper middle income
# URY   Uruguay                                               LCN       HIC
# USA   United States                                         NAC       HIC
# UZB   Uzbekistan                                            ECS       LMC
# VCT   St. Vincent and the Grenadines                        LCN       UMC
# VEN   Venezuela, RB                                         LCN       INX
# VGB   British Virgin Islands                                LCN       HIC
# VIR   Virgin Islands (U.S.)                                 LCN       HIC
# VNM   Vietnam                                               EAS       LMC
# VUT   Vanuatu                                               EAS       LMC
# WLD   World
# WSM   Samoa                                                 EAS       LMC
# XKX   Kosovo                                                ECS       UMC
# YEM   Yemen, Rep.                                           MEA       LIC
# ZAF   South Africa                                          SSF       UMC
# ZMB   Zambia                                                SSF       LMC
# ZWE   Zimbabwe                                              SSF       LMC
#       266 elements

# %%
wb.series.info(q="energy")
# Out:
# id                    value
# --------------------  ---------------------------------------------------------------------------------
# EG.EGY.PRIM.PP.KD     Energy intensity level of primary energy (MJ/$2011 PPP GDP)
# EG.FEC.RNEW.ZS        Renewable energy consumption (% of total final energy consumption)
# EG.GDP.PUSE.KO.PP     GDP per unit of energy use (PPP $ per kg of oil equivalent)
# EG.GDP.PUSE.KO.PP.KD  GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)
# EG.IMP.CONS.ZS        Energy imports, net (% of energy use)
# EG.USE.COMM.CL.ZS     Alternative and nuclear energy (% of total energy use)
# EG.USE.COMM.FO.ZS     Fossil fuel energy consumption (% of total)
# EG.USE.COMM.GD.PP.KD  Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)
# EG.USE.PCAP.KG.OE     Energy use (kg of oil equivalent per capita)
# EN.ATM.METH.EG.KT.CE  Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# EN.ATM.METH.EG.ZS     Energy related methane emissions (% of total)
# EN.ATM.NOXE.EG.KT.CE  Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
# EN.ATM.NOXE.EG.ZS     Nitrous oxide emissions in energy sector (% of total)
# IE.PPI.ENGY.CD        Investment in energy with private participation (current US$)
# IE.PPN.ENGY.CD        Public private partnerships investment in energy (current US$)
# NY.ADJ.DNGY.CD        Adjusted savings: energy depletion (current US$)
# NY.ADJ.DNGY.GN.ZS     Adjusted savings: energy depletion (% of GNI)
#                       17 elements

# %%
Table_result= wb.data.DataFrame('EG.FEC.RNEW.ZS', ['CAN','USA','DEU','FRA','GBR','JPN','RUS','ITA'],time=range(2014,2016))

result = Table_result.to_json(orient="split")
parsed = json.loads(result)

years=parsed['columns']
countries=parsed['index']
values=parsed['data']

arrays=[]
i=0
indexc=0
for c in countries:
    for n in values[i]:
        list_array=(c,years[indexc],n)
        arrays.append(list_array)
        indexc=indexc+1
    indexc=0
    i+=1

final =pd.DataFrame(arrays, columns = ['Country','Year','Value'])
print(final.to_string(index = False))

final.to_csv('Import_table.csv', encoding='utf-8')
# Out:
# Country   Year     Value
#     CAN YR2014 22.416800
#     CAN YR2015 22.642200
#     DEU YR2014 14.024700
#     DEU YR2015 14.550300
#     FRA YR2014 13.353400
#     FRA YR2015 13.483800
#     GBR YR2014  7.360400
#     GBR YR2015  8.587700
#     ITA YR2014 17.131599
#     ITA YR2015 16.570499
#     JPN YR2014  5.719900
#     JPN YR2015  6.323400
#     RUS YR2014  3.296100
#     RUS YR2015  3.200300
#     USA YR2014  9.220500
#     USA YR2015  9.033900

# %%
Table_result= wb.data.DataFrame('EG.FEC.RNEW.ZS',['ESP'],(2008,2020))
Table_result
# Out:
#          YR2008  YR2020
# economy
# ESP      9.7445     NaN

# %%
#API for Emisions
url1='https://www.climatewatchdata.org/api/v1/data/historical_emissions'

r=requests.get(url1,params={'data_sources':111,'gases':326,"sectors":'1329',"regions":'USA',"start_year":2016,'end_year':2016,'sort_col':'regions','sort_dir':'ASC'})
r.text
# Out:
# '{"data":[{"id":661531,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Total excluding LUCF","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":5907.27}]},{"id":661532,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Total including LUCF","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":5676.92}]},{"id":661533,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Energy","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":5172.83}]},{"id":661534,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Industrial Processes","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":222.02}]},{"id":661535,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Agriculture","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":381.4}]},{"id":661536,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Waste","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":131.03}]},{"id":661537,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Land-Use Change and Forestry","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":-230.36}]},{"id":661538,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Bunker Fuels","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":136.85}]},{"id":661539,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Electricity/Heat","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":2145.51}]},{"id":661540,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Manufacturing/Construction","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":439.02}]},{"id":661541,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Transportation","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":1711.22}]},{"id":661542,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Building","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":496.47}]},{"id":661543,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Other Fuel Combustion","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":94.48}]},{"id":661544,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Fugitive Emissions","gas":"All GHG","unit":"MtCO₂e","emissions":[{"year":2016,"value":286.11}]},{"id":661545,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Total excluding LUCF","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":4888.64}]},{"id":661546,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Total including LUCF","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":4656.84}]},{"id":661547,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Energy","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":4849.2}]},{"id":661548,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Industrial Processes","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":39.44}]},{"id":661549,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Land-Use Change and Forestry","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":-231.8}]},{"id":661550,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Bunker Fuels","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":136.85}]},{"id":661551,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Electricity/Heat","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":2145.51}]},{"id":661552,"iso_code3":"USA","country":"United States","data_source":"CAIT","sector":"Manufacturing/Construction","gas":"CO2","unit":"MtCO₂e","emissions":[{"year":2016,"value":4 ...

# %%
r.status_code
# Out:
# 200

# %%
#check the headers
a=requests.head('https://www.climatewatchdata.org/api/v1/data/historical_emissions/meta', timeout=2.50)

# %%
a.text
# Out:
# ''
