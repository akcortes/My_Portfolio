# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)
diamonds
# Out:
#        Unnamed: 0.1  carat        cut color clarity  depth  table   price  \
# 0                 1   0.23      Ideal     E     SI2   61.5   55.0   326.0
# 1                 2   0.21    Premium     E     SI1   59.8   61.0   326.0
# 2                 3   0.23       Good     E     VS1   56.9   65.0   327.0
# 3                 4   0.29    Premium     I     VS2   62.4   58.0   334.0
# 4                 5   0.31       Good     J     SI2   63.3   58.0   335.0
# ...             ...    ...        ...   ...     ...    ...    ...     ...
# 53935         53936   0.72      Ideal     D     SI1   60.8   57.0  2757.0
# 53936         53937   0.72       Good     D     SI1   63.1   55.0  2757.0
# 53937         53938   0.70  Very Good     D     SI1   62.8   60.0  2757.0
# 53938         53939   0.86    Premium     H     SI2   61.0   58.0  2757.0
# 53939         53940   0.75      Ideal     D     SI2   62.2   55.0  2757.0
#
#           x     y     z  scale_clarity  scale_color  validate_z
# 0      3.95  3.98  2.43              1            5       False
# 1      3.89  3.84  2.31              2            5       False
# 2      4.05  4.07  2.31              4            5       False
# 3      4.20  4.23  2.63              3            1       False
# 4      4.34  4.35  2.75              1            0       False
# ...     ...   ...   ...            ...          ...         ...
# 53935  5.75  5.76  3.50              2            6       False
# 53936  5.69  5.75  3.61              2            6       False
# 53937  5.66  5.68  3.56              2            6       False
# 53938  6.15  6.12  3.74              1            2       False
# 53939  5.83  5.87  3.64              1            6       False
#
# [53940 rows x 14 columns]

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
d=diamonds[['color','scale_color','price','carat','table','x','y','z']].groupby(['color']).agg('mean')
d.sort_values('price',ascending=False)
# Out:
#        scale_color        price     carat      table         x         y  \
# color
# J                0  5323.818020  1.162137  57.812393  6.519338  6.518105
# I                1  5091.874954  1.026927  57.577278  6.222826  6.222730
# H                2  4486.669196  0.911799  57.517811  5.984776  5.981484
# G                3  3999.135671  0.771190  57.288629  5.678549  5.681198
# F                4  3724.886397  0.736538  57.433536  5.616727  5.620634
# D                6  3169.954096  0.657795  57.404590  5.417851  5.421928
# E                5  3076.752475  0.657867  57.491201  5.411580  5.416949
#
#               z
# color
# J      4.033251
# I      3.846369
# H      3.699147
# G      3.507966
# F      3.465938
# D      3.343320
# E      3.337767

# %%
diamonds.corr(method ='pearson')
# Out:
#                Unnamed: 0.1     carat     depth     table     price         x  \
# Unnamed: 0.1       1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.406249
# carat             -0.377983  1.000000  0.028224  0.181618  0.921591  0.977765
# depth             -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025097
# table             -0.100830  0.181618 -0.295779  1.000000  0.127134  0.196130
# price             -0.306873  0.921591 -0.010647  0.127134  1.000000  0.887227
# x                 -0.406249  0.977765 -0.025097  0.196130  0.887227  1.000000
# y                 -0.406415  0.975719 -0.028550  0.189514  0.887762  0.997427
# z                 -0.408885  0.976256  0.096379  0.155810  0.881924  0.990827
# scale_clarity      0.208598 -0.352841 -0.067384 -0.160327 -0.146800 -0.373009
# scale_color        0.095098 -0.291437 -0.047279 -0.026465 -0.172511 -0.270780
# validate_z        -0.000194 -0.009264  0.009474 -0.005126 -0.007370 -0.012273
#
#                       y         z  scale_clarity  scale_color  validate_z
# Unnamed: 0.1  -0.406415 -0.408885       0.208598     0.095098   -0.000194
# carat          0.975719  0.976256      -0.352841    -0.291437   -0.009264
# depth         -0.028550  0.096379      -0.067384    -0.047279    0.009474
# table          0.189514  0.155810      -0.160327    -0.026465   -0.005126
# price          0.887762  0.881924      -0.146800    -0.172511   -0.007370
# x              0.997427  0.990827      -0.373009    -0.270780   -0.012273
# y              1.000000  0.990381      -0.367276    -0.270211   -0.012556
# z              0.990381  1.000000      -0.376497    -0.274974   -0.011326
# scale_clarity -0.367276 -0.376497       1.000000    -0.025631    0.008600
# scale_color   -0.270211 -0.274974      -0.025631     1.000000   -0.000606
# validate_z    -0.012556 -0.011326       0.008600    -0.000606    1.000000

# %%
diamonds.describe()
# Out:
#        Unnamed: 0.1         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z  scale_clarity   scale_color
# count  53932.000000  53933.000000  53932.000000   53940.000000  53940.000000
# mean       5.732007      5.734158      3.539735       3.051020      3.405803
# std        1.119670      1.113268      0.692051       1.647136      1.701105
# min        3.730000      3.680000      1.070000       0.000000      0.000000
# 25%        4.710000      4.720000      2.910000       2.000000      2.000000
# 50%        5.700000      5.710000      3.530000       3.000000      3.000000
# 75%        6.540000      6.540000      4.040000       4.000000      5.000000
# max       10.740000     19.278421      8.060000       7.000000      6.000000

# %%
#your comments here
#worst colors there is a relationship between the color and the price (worst  -higher price)

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here
#carat. because of the results. they are all coorelated. More carat more price

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
d=diamonds[['color','scale_color','price','carat','table','x','y','z','scale_clarity']].groupby(['color']).agg('mean')
d.sort_values('scale_color',ascending=False)
# Out:
#        scale_color        price     carat      table         x         y  \
# color
# D              6.0  3169.954096  0.657795  57.404590  5.417851  5.421928
# E              5.0  3076.752475  0.657867  57.491201  5.411580  5.416949
# F              4.0  3724.886397  0.736538  57.433536  5.616727  5.620634
# G              3.0  3999.135671  0.771190  57.288629  5.678549  5.681198
# H              2.0  4486.669196  0.911799  57.517811  5.984776  5.981484
# I              1.0  5091.874954  1.026927  57.577278  6.222826  6.222730
# J              0.0  5323.818020  1.162137  57.812393  6.519338  6.518105
#
#               z  scale_clarity
# color
# D      3.343320       2.691513
# E      3.337767       2.969889
# F      3.465938       3.133934
# G      3.507966       3.463425
# H      3.699147       2.933646
# I      3.846369       2.964035
# J      4.033251       2.776353

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here
# worst colors there is a relationship between the color and the price (worst  - higher price)

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here

fig, [ax1, ax2, ax3] = plt.subplots(3,1,figsize=(16,20))
ax1.plot(d['scale_color'],d['price'])
ax1.set_title('Color Vs Price')   
ax1.set_xlabel('Color Scale')     
ax1.set_ylabel('Price')   

ax2.plot(d['scale_color'],d['carat'])
ax2.set_title('Color Vs Carat')
ax2.set_xlabel('Color Scale')
ax2.set_ylabel('Carat')

ax3.plot(d['scale_color'],d['scale_clarity'])
ax3.set_title('Color Vs Scale_clarity')
ax3.set_xlabel('Color Scale')
ax3.set_ylabel('Scale_clarity')

plt.show()

# %%
#your comments here
#relationship between the color and the price 
#relationship between the color and the carat

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
d=diamonds[['color','scale_color','price','carat','table','x','y','z','scale_clarity']].groupby(['carat']).agg('mean')
d.sort_values('carat',ascending=False)
d.head(20)
# Out:
#        scale_color       price      table         x         y         z  \
# carat
# 0.20      5.166667  365.166667  59.333333  3.786667  3.753333  2.303333
# 0.21      5.444444  380.222222  58.444444  3.874444  3.837778  2.332222
# 0.22      4.800000  391.400000  60.400000  3.898000  3.848000  2.386000
# 0.23      4.518771  486.143345  58.034130  3.946382  3.973379  2.431468
# 0.24      4.185039  505.185039  57.488189  3.990157  4.019331  2.465591
# 0.25      4.146226  550.924528  57.363208  4.062500  4.086934  2.506934
# 0.26      3.928854  550.897233  56.911858  4.102688  4.124704  2.536364
# 0.27      4.047210  574.759657  56.778970  4.159142  4.181588  2.567897
# 0.28      3.898990  580.121212  56.863636  4.207172  4.233687  2.595707
# 0.29      3.776923  601.192308  56.846154  4.262846  4.290538  2.624000
# 0.30      3.605223  680.301843  57.134217  4.299443  4.308061  2.664351
# 0.31      3.622499  708.235660  56.700845  4.353219  4.360912  2.690422
# 0.32      3.567935  720.144022  56.592337  4.399821  4.406995  2.717755
# 0.33      3.569386  765.731707  56.777544  4.449521  4.456569  2.741447
# 0.34      3.746154  756.380220  56.798681  4.495363  4.499560  2.768714
# 0.35      3.830585  800.676162  56.776162  4.544693  4.550825  2.801049
# 0.36      3.952797  781.381119  56.877797  4.580927  4.590105  2.819266
# 0.37      3.873096  816.071066  57.169289  4.625228  4.632944  2.839949
# 0.38      3.722388  904.441791  56.833284  4.662403  4.677313  2.866955
# 0.39      3.474874  922.331658  57.090955  4.696156  4.713593  2.898116
#
#        scale_clarity
# carat
# 0.20        2.833333
# 0.21        2.666667
# 0.22        2.600000
# 0.23        4.901024
# 0.24        4.972441
# 0.25        4.853774
# 0.26        4.723320
# 0.27        4.729614
# 0.28        4.727273
# 0.29        4.638462
# 0.30        3.951613
# 0.31        3.919964
# 0.32        3.817935
# 0.33        4.053827
# 0.34        3.562637
# 0.35        3.764618
# 0.36        3.358392
# 0.37        3.505076
# 0.38        3.729851
# 0.39        3.959799

# %%
#your comments
#relationship between the carat and the price, and the dimensions

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
diamonds['carat'].plot.hist(bins=60,figsize=(15,8))
#the values are too concentrated in one part of the data , between 0-0.5
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
diamonds['carat'].value_counts()
# Out:
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.11       1
# 3.50       1
# 3.67       1
# 5.01       1
# 3.51       1
# Name: carat, Length: 273, dtype: int64

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
d=diamonds[['color','scale_color','price','carat','table','x','y','z','scale_clarity']].groupby(['table']).agg('mean')
d.sort_values('table',ascending=False)
d.head(20)
# Out:
#        scale_color         price     carat         x         y         z  \
# table
# 43.0      1.000000   4997.000000  1.040000  6.450000  6.410000  4.040000
# 44.0      5.000000    474.000000  0.290000  4.200000  4.240000  2.650000
# 49.0      3.000000   2290.500000  0.650000  5.355000  5.320000  3.425000
# 50.0      3.000000   8995.500000  1.510000  7.380000  7.295000  4.510000
# 50.1      2.000000   3353.000000  0.940000  6.130000  6.170000  4.060000
# 51.0      3.222222   4063.666667  0.883333  5.995556  5.941111  3.780000
# 51.6      0.000000  13203.000000  2.000000  8.140000  8.180000  4.970000
# 52.0      3.517857   4342.000000  0.871071  5.877143  5.870179  3.696429
# 52.4      4.000000   1679.000000  0.500000  5.070000  5.110000  3.180000
# 52.8      2.500000    652.500000  0.300000  4.285000  4.330000  2.690000
# 53.0      3.308642   3228.248677  0.684885  5.427739  5.441466  3.395118
# 53.1      2.333333   1146.666667  0.396667  4.676667  4.703333  2.936667
# 53.2      2.400000   2863.800000  0.706000  5.446000  5.486000  3.410000
# 53.3      3.250000   3814.375000  0.608750  5.155000  5.183750  3.226250
# 53.4      3.250000   3253.333333  0.615833  5.324167  5.361667  3.335000
# 53.5      3.500000   3072.916667  0.587500  5.123333  5.165833  3.203333
# 53.6      3.050000   2766.700000  0.638500  5.251500  5.286000  3.279000
# 53.7      3.160000   2385.960000  0.551200  5.113200  5.149600  3.196800
# 53.8      3.590909   1408.545455  0.453182  4.832273  4.867727  3.026818
# 53.9      2.892857   3123.071429  0.631786  5.264286  5.299643  3.283214
#
#        scale_clarity
# table
# 43.0        4.000000
# 44.0        4.000000
# 49.0        3.000000
# 50.0        2.000000
# 50.1        1.000000
# 51.0        2.666667
# 51.6        4.000000
# 52.0        2.892857
# 52.4        4.000000
# 52.8        4.500000
# 53.0        3.474427
# 53.1        4.666667
# 53.2        4.000000
# 53.3        4.125000
# 53.4        4.333333
# 53.5        4.333333
# 53.6        3.750000
# 53.7        4.240000
# 53.8        4.045455
# 53.9        3.750000

# %%
#your comments here
#no corelated with any of the other values

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
d=diamonds[['color','scale_color','price','carat','table','x','y','z','scale_clarity']].groupby(['scale_clarity']).agg('mean')
d.sort_values('scale_clarity',ascending=False)
d.head(20)
# Out:
#                scale_color        price     carat      table         x  \
# scale_clarity
# 0                 2.968961  3924.168691  1.283846  58.303779  6.761093
# 1                 3.469980  5063.028606  1.077648  57.927181  6.404157
# 2                 3.448450  3996.001148  0.850482  57.662541  5.888383
# 3                 3.494208  3924.989395  0.763935  57.417401  5.658633
# 4                 3.161792  3839.455391  0.727158  57.315151  5.572860
# 5                 3.569483  3283.737071  0.596202  57.024990  5.218454
# 6                 3.351573  2523.114637  0.503321  56.884460  4.961721
# 7                 3.101676  2864.839106  0.505123  56.507207  4.968402
#
#                       y         z
# scale_clarity
# 0              6.709379  4.224688
# 1              6.395603  3.952642
# 2              5.888256  3.640636
# 3              5.659782  3.492788
# 4              5.580017  3.437925
# 5              5.232118  3.221465
# 6              4.976437  3.062132
# 7              4.989827  3.061659

# %%
#your comments here
#scale clarity related with the carat

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#your thoughts here
#It matches my hypothesis . carat is the valu more related to the price, and the dimensions

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here
#carat and the dimensions
#carat and price

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
#it fits the results

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# /Users/anak/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493305264354899

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
#Carat is correlated with price

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
