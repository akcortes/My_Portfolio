# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
import json
import requests
import pandas as pd

# %%
pip install stackapi
# Out:
# ...
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5857 sha256=459a19fe19212deb8d8c68f9ba3a5e357767f581603aea1b21a770c17871cdbf
#   Stored in directory: /Users/anak/Library/Caches/pip/wheels/15/38/46/ce92f4ec7e81b3da9b2bae72b572a49a2b1b025cdce325cc01
# Successfully built stackapi
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI

# %%
# your code here
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments',fromdate=1638835200, todate=1636243200)

# %%
comments
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 298,
#  'total': 0,
#  'items': []}

# %%
SITE2 = StackAPI('stackoverflow')
comments2 = SITE2.fetch('questions')

# %%
questions = pd.DataFrame(comments2)
questions
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              292      0
# 1          0      True     5        300              292      0
# 2          0      True     5        300              292      0
# 3          0      True     5        300              292      0
# 4          0      True     5        300              292      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              292      0
# 496        0      True     5        300              292      0
# 497        0      True     5        300              292      0
# 498        0      True     5        300              292      0
# 499        0      True     5        300              292      0
#
#                                                  items
# 0    {'tags': ['python', 'json'], 'owner': {'reputa...
# 1    {'tags': ['docker', 'nginx', 'docker-compose',...
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['items']

flat = flatten(questions, nested_columns)


flat.head(10)
# Out:
#    backoff  has_more  page  quota_max  quota_remaining  total  \
# 0        0      True     5        300              292      0
# 1        0      True     5        300              292      0
# 2        0      True     5        300              292      0
# 3        0      True     5        300              292      0
# 4        0      True     5        300              292      0
# 5        0      True     5        300              292      0
# 6        0      True     5        300              292      0
# 7        0      True     5        300              292      0
# 8        0      True     5        300              292      0
# 9        0      True     5        300              292      0
#
#                                           items_tags  \
# 0                                     [python, json]
# 1  [docker, nginx, docker-compose, reverse-proxy,...
# 2                                            [mysql]
# 3      [json, authentication, curl, rss, rss-reader]
# ...

# %%
print(flat.items_title.value_counts())
# Out:
# typescript tsc -p fails ONLY in docker build                                          2
# How to paste clipboard output between string?                                         2
# TestCafe assertions over multiple selectors in Promise.allSettled seems misleading    2
# How to iterate each date folder and read parquet file from s3 using python?           2
# Removing PII from URL in an SPA (GTM/GA4)                                             1
#                                                                                      ..
# How To Use rows.NextResultSet() in Golang with database/sql?                          1
# Content Security Policy contains an invalid source                                    1
# How to switch from vector::at() to [] when building Release                           1
# How to get rid of errors &quot;jitter buffer full&quot; in ffmpeg?                    1
# Docker Hub and git submodules                                                         1
# ...

# %%
SITE3 = StackAPI('stackoverflow')
comments3 = SITE3.fetch('answers')

# %%
answerss = pd.DataFrame(comments2)
answerss
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0         10      True     5        300              286      0
# 1         10      True     5        300              286      0
# 2         10      True     5        300              286      0
# 3         10      True     5        300              286      0
# 4         10      True     5        300              286      0
# ..       ...       ...   ...        ...              ...    ...
# 495       10      True     5        300              286      0
# 496       10      True     5        300              286      0
# 497       10      True     5        300              286      0
# 498       10      True     5        300              286      0
# 499       10      True     5        300              286      0
#
#                                                  items
# 0    {'owner': {'reputation': 189, 'user_id': 18043...
# 1    {'owner': {'reputation': 11, 'user_id': 172610...
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['items']

flat2 = flatten(answerss, nested_columns)


flat2.head(10)
# Out:
#    backoff  has_more  page  quota_max  quota_remaining  total  \
# 0       10      True     5        300              286      0
# 1       10      True     5        300              286      0
# 2       10      True     5        300              286      0
# 3       10      True     5        300              286      0
# 4       10      True     5        300              286      0
# 5       10      True     5        300              286      0
# 6       10      True     5        300              286      0
# 7       10      True     5        300              286      0
# 8       10      True     5        300              286      0
# 9       10      True     5        300              286      0
#
#                                          items_owner items_is_accepted  \
# 0  {'reputation': 189, 'user_id': 18043, 'user_ty...             False
# 1  {'reputation': 11, 'user_id': 17261090, 'user_...             False
# ...

# %%
print(comments3)
# Out:
# {'backoff': 10, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 272, 'total': 0, 'items': [{'owner': {'reputation': 7, 'user_id': 12203194, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/4c8e0025bb076345fce2ed35caaf6236?s=256&d=identicon&r=PG&f=1', 'display_name': 'SzK', 'link': 'https://stackoverflow.com/users/12203194/szk'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1638890640, 'last_edit_date': 1638890640, 'creation_date': 1638877973, 'answer_id': 70259665, 'question_id': 47332700, 'content_license': 'CC BY-SA 4.0'}, {'owner': {'reputation': 333, 'user_id': 3642359, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/0823e18ba92d5f837c6d6f5be7de5b61?s=256&d=identicon&r=PG', 'display_name': 'rafiss', 'link': 'https://stackoverflow.com/users/3642359/rafiss'}, 'is_accepted': False, 'score': 0, 'last_activity_date': 1638890639, 'creation_date': 1638890639, 'answer_id': 70262750, 'question_id': 70238
# ...

# %%
print(flat2.items_answer_id.value_counts())
# Out:
# 70262452    2
# 70262037    2
# 70262102    2
# 70261954    2
# 70261955    2
#            ..
# 64930108    1
# 70262075    1
# 70262074    1
# 70262073    1
# 70248923    1
# Name: items_answer_id, Length: 488, dtype: int64

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
SITE = StackAPI('stackoverflow')
mostvoted = SITE.fetch('questions', fromdate=1638835200, todate=1638835200, min=5, tagged='python', sort='votes')

# %%
mostvoted
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 256,
#  'total': 0,
#  'items': []}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
SITE = StackAPI('stackoverflow')
answer_id = SITE.fetch('answers', ids=[6473])

# %%
SITE = StackAPI('stackoverflow')
answer_id_2 = SITE.fetch('answers', ids=[6784])

# %%
answer_id
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 242,
#  'total': 0,
#  'items': []}

# %%
answer_id_2
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 240,
#  'total': 0,
#  'items': [{'owner': {'reputation': 29899,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
