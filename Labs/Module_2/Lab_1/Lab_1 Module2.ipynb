# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='Method1 XY')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Method 1")
plt.legend()
plt.show()

plt.plot(x, z, label='Method1 XZ')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Method 1")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1,ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title('XY')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('XZ')   
ax2.set_xlabel('x label')     
ax2.set_ylabel('Z label') 

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1,ax2] = plt.subplots(nrows=2, ncols=1,figsize=(10, 4),facecolor='red')
ax1.plot(x,y)
ax1.set_title('XY')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('XZ')   
ax2.set_xlabel('x label')     
ax2.set_ylabel('Z label') 


plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
fig, [ax1,ax2] = plt.subplots(nrows=2, ncols=1,figsize=(10, 4),facecolor='yellow')

y=x^2
ax1.plot(x,y,label='linear')
ax1.set_title('XY')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   
ax1.legend(loc="upper left", bbox_to_anchor=[0, 1],
                 ncol=2, shadow=True, title="Legend", fancybox=True)

plt.yscale('linear')

y=np.exp(x)
ax2.plot(x,z,label='cuadratic')
ax2.set_title('XZ')   
ax2.set_xlabel('x label')     
ax2.set_ylabel('Z label') 
ax2.legend(loc="upper left", bbox_to_anchor=[0, 1],
                 ncol=2, shadow=True, title="Legend", fancybox=True)

plt.yscale('log')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
data=pd.read_csv('/Users/anak/DAFT_NOV_21_01-main/module_2/Lab_1_Matplotlib_and_Seaborn/Fitbit2.csv')
data
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here



ax1=data[['Steps','Work_or_Weekend']].groupby(['Work_or_Weekend']).agg('mean')
ax2=data[['Steps','Months_encoded']].groupby(['Months_encoded'] ).agg('mean')


ax1.plot.bar(figsize=(12,4))
ax2.plot(figsize=(12,4))




plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
for i in range(len(data['Minutes Lightly Active'])):
    plt.figure(1)
    plt.scatter(x=data['Minutes Lightly Active'][i],y=data['Steps'][i],c='#7f7f7f')
    plt.figure(2)
    plt.scatter(x=data['Minutes Very Active'][i],y=data['Steps'][i])
    plt.figure(3)
    plt.scatter(x=data['Minutes Sedentary'][i],y=data['Steps'][i])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
df=pd.read_csv('/Users/anak/DAFT_NOV_21_01-main/module_2/Lab_1_Matplotlib_and_Seaborn/titanic.csv')
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
df.select_dtypes(include=['float64','int','bool'])
#Passenger id, age,fare
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

df.select_dtypes(exclude=['float64','int','bool'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set_theme()




# Apply the default theme


# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(data=tips,x="total_bill", y="tip", col="time",hue="smoker", style="smoker", size="size")

# Create a visualization

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

df['Age'].plot.hist(figsize=(15,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Age'].value_counts()
# Out:
# 24.000000    47
# 22.000000    43
# 21.000000    41
# 30.000000    40
# 18.000000    39
#              ..
# 80.000000     1
# 46.914582     1
# 50.684299     1
# 35.076081     1
# 60.500000     1
# Name: Age, Length: 193, dtype: int64

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here




plt.figure(1)
plt.subplot(211)


df['Age'].plot.hist(figsize=(15,6),bins=10)
plt.figure(2)
plt.subplot(211)
 
df['Age'].plot.hist(figsize=(15,6),bins=20)

plt.figure(3)
plt.subplot(211)
df['Age'].plot.hist(figsize=(15,6),bins=50)


plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

#more bins more exact the graph is

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(data=df, x=df['Age'], bins=10)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
df['Gender'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Method 2 - seaborn
# your code here

sns.catplot(x='Gender',data=df,kind='count')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.catplot(x='Pclass',data=df,kind='count')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot("Age", data=df)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
"""
your comments here

the average is between 20 and 30
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
the average is between 20 and 30
the mad and min 
and clues about the frequency

"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.figure(1)
sns.violinplot(x="Age", data=df)
plt.figure(2)
ax = sns.boxplot(x="Age", data=df)
plt.figure(3)
ax = sns.histplot(x="Age", data=df)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
the age follows a distribution more or less skewed to the right
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
df.plot.scatter(x='Age',y='Fare')
# your code here
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# Method 2 - seaborn
# your code here
sns.regplot(x = "Fare", y="Age", data=df, fit_reg = False,scatter_kws={"alpha": 0.2})
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(df.corr());

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Parch and SibSp
Pclass and Fare
Age Pclass
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.violinplot(x=df["Pclass"],y=df["Age"])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(df, col = "Gender")
g.map(plt.hist,'Age')
